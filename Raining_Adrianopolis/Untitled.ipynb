# %% [markdown]
# **File data Analysis and Treatment**

# %% [markdown]
# There 2 files in the data folder containing two stations with meteriological information
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Opening we see that the data stored in excel file need to be on a good format for reading on pandas:
#
# ![image.png](attachment:image.png)
#
#
# There are many columns that are useless for our investigation (like Status column and consistency level) so we're gona treat the .csv file before opening with python.

# %% [markdown]
# First eliminate the summary lines that are describing the station:
#
# ![image.png](attachment:image.png)
#
# Then eliminate some columns that are not necessary

# %% [markdown]
# After that inicial treatment we have this in the .csv file:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# We can do some inicial analysis in the excel using the conditional formatting:
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# We can see that are manny missing data in this dataset,
#
# ![image-3.png](attachment:image-3.png)
